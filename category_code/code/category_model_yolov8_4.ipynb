# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Fri Jul 28 07:36:02 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %pip install Ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.0/605.0 kB 6.0 MB/s eta 0:00:00
# ...

# %%
# studypmy
# 카테고리 정리 후
# %cd /content/drive/MyDrive/DL_project/DL_model/DL_category_project
# Out:
# /content/drive/.shortcut-targets-by-id/1vjGnShCMawgKAhDmf-b8qUK1m6qja5Wy/DL_category_project

# %%
# studypmy
# dataset PATH
# !unzip "/content/drive/MyDrive/DL_project/DL_model/DL_category_project/after_remove_dataset.zip" -d /content/
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/after_remove_dataset/train/labels/52394.txt
#   inflating: /content/__MACOSX/after_remove_dataset/train/labels/._52394.txt
#   inflating: /content/after_remove_dataset/train/labels/609197.txt
#   inflating: /content/__MACOSX/after_remove_dataset/train/labels/._609197.txt
#   inflating: /content/after_remove_dataset/train/labels/862461.txt
#   inflating: /content/__MACOSX/after_remove_dataset/train/labels/._862461.txt
#   inflating: /content/after_remove_dataset/train/labels/1145182.txt
#   inflating: /content/__MACOSX/after_remove_dataset/train/labels/._1145182.txt
#   inflating: /content/after_remove_dataset/train/labels/773149.txt
#   inflating: /content/__MACOSX/after_remove_dataset/train/labels/._773149.txt
#   inflating: /content/after_remove_dataset/train/labels/713865.txt
#   inflating: /content/__MACOSX/after_remove_dataset/train/labels/._713865.txt
# ...

# %%
# # custom 데이터로 train 수행
# !yolo train model='/content/drive/MyDrive/zerobase/team_project/DL_category_project/best_pt/best.pt' data='/content/drive/MyDrive/zerobase/team_project/DL_category_project/config/category_after_remove.yaml' epochs=4 imgsz=640 batch=32
# Out:
# Ultralytics YOLOv8.0.141 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# 이어서 학습
from ultralytics import YOLO
model = YOLO('/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/runs/detect/train9/weights/last.pt')
model.resume = True
# train the model
results = model. train(
    data ='/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/config/category_after_remove.yaml',
    batch=64,
    epochs=8
)
# Out:
# Ultralytics YOLOv8.0.143 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# # 이어서 학습
# from ultralytics import YOLO
# model = YOLO('/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/runs/detect/train8/weights/last.pt')
# model.resume = True
# # train the model
# results = model. train(
#     data ='/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/config/category_after_remove.yaml',
#     batch=64,
#     epochs=8
# )
# Out:
# Ultralytics YOLOv8.0.143 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# # 이어서 학습
# from ultralytics import YOLO
# model = YOLO('/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/runs/detect/train7/weights/last.pt')
# model.resume = True
# # train the model
# results = model. train(
#     data ='/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/config/category_after_remove.yaml',
#     batch=64,
#     epochs=8
# )
# Out:
# Ultralytics YOLOv8.0.143 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# # 이어서 학습
# from ultralytics import YOLO
# model = YOLO('/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/runs/detect/train6/weights/last.pt')
# model.resume = True
# # train the model
# results = model. train(
#     data ='/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/config/category_after_remove.yaml',
#     batch=64,
#     epochs=8
# )
# Out:
# Ultralytics YOLOv8.0.143 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# # 이어서 학습
# from ultralytics import YOLO
# model = YOLO('/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/runs/detect/train5/weights/last.pt')
# model.resume = True
# # train the model
# results = model. train(
#     data ='/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/config/category_after_remove.yaml',
#     batch=64,
#     epochs=4
# )
# Out:
# Ultralytics YOLOv8.0.143 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# # 이어서 학습
# from ultralytics import YOLO
# model = YOLO('/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/runs/detect/train2/weights/last.pt')
# model.resume = True
# # train the model
# results = model. train(
#     data ='/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/config/category_after_remove.yaml',
#     batch=64,
#     epochs=3
# )
# Out:
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# from ultralytics import YOLO
# model = YOLO('/content/drive/MyDrive/Team_project/DL_project_2team/DL_model/DL_category_project/runs/detect/train6/weights/last.pt')
# model.resume = True
# # train the model
# results = model. train(
#   batch=64,
#   epochs=4
# )
